# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# import cv2
import PIL
# %matplotlib inline

# %%
# !pwd
# Out:
# /home/ubuntu/EDA

# %%
MensShoes=pd.read_csv('/home/ubuntu/Data/MensShoes.csv')
menPixel=np.load('/home/ubuntu/Data/menPixel.npy')

# %%
MensShoes.head(1)
# Out:
#    Unnamed: 0                                              image  \
# 0           0  http://s2.onlineshoes.com/images/br008/mens-ne...
#
#             category                 name price sale_price original_price
# 0  Men's New Balance  MW577 - Hook & Loop   NaN     $59.99         $76.95

# %%
# def gray(img):
#     return (0.2989 * img[:,:,0] + 0.5870 *img[:,:,1]  + 0.1140 * img[:,:,2]).astype('uint8')

# %%
plt.imshow(menPixel[:,:,:,93].astype('uint8'))
plt.axis('off')
img=menPixel[:,:,:,93].astype('uint8')
plt.imshow(img)

# %%
from PIL import Image
from pylab import *
Image.Image
imAdd = '/Users/Shahram/Desktop/DSI/DSI_SM_01/CapStone/Data/shoe.jpeg'
pil_im = Image.open(imAdd).convert('L')
pil_im.show()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-7-c5b8e31a4b5a> in <module>()
#       3 Image.Image
#       4 imAdd = '/Users/Shahram/Desktop/DSI/DSI_SM_01/CapStone/Data/shoe.jpeg'
# ----> 5 pil_im = Image.open(imAdd).convert('L')
#       6 pil_im.show()
#
# /usr/lib/python2.7/dist-packages/PIL/Image.pyc in open(fp, mode)
#    1994     if isPath(fp):
#    1995         filename = fp
# -> 1996         fp = builtins.open(fp, "rb")
#    1997     else:
#    1998         filename = ""
#
# IOError: [Errno 2] No such file or directory: '/Users/Shahram/Desktop/DSI/DSI_SM_01/CapStone/Data/shoe.jpeg'

# %%
# This function takes a list of images and plots them in one frame.
# For the current version it works for images with the same shape 
def multiple_image_show(imL):
    n_rows=np.floor(np.sqrt(len(imL))).astype(int)
    temp_arr=np.concatenate( [[np.concatenate([imL[i] for i in range((j-1)*n_rows,j*n_rows)],axis=1)] for j in range(0,n_rows)],axis=1)
    print "Missing " + str(int(len(imL) - n_rows*n_rows)) + " Input Image/s"
    plt.imshow(temp_arr[0,:,:,:].astype('uint8'))
    plt.axis('off')
    plt.show()

# %%
multiple_image_show([menPixel[:,:,:,i] for i in range(5000,5300)])
# Out:
# Missing 11 Input Image/s

# %%
plt.imshow(menPixel.mean((2,3)))
plt.title('Average Value of Pixels Men Shoes')

# %%
im=menPixel[:,:,0,20].astype('uint8')
plt.imshow(im)
plt.title('Red Component of Image')

# %%
im=menPixel[:,:,1,20].astype('uint8')
plt.imshow(im)
plt.title('Green Component of Image')

# %%
im=menPixel[:,:,2,20].astype('uint8')
plt.imshow(im)
plt.title('Blue Component of Image')

# %%
! sudo conda install sklearn
# Out:
# sudo: conda: command not found

# %% [markdown]
# ### Birch Clustering

# %%
np.shape(menPixel)
# Out:
# (120, 120, 3, 9929)

# %%
from sklearn.cluster import Birch
n_samples=100
dn=np.transpose(np.reshape(menPixel[:,:,:,0:n_samples],(120*120*3,n_samples)))

brc = Birch(branching_factor=50, n_clusters=3, threshold=0.5,compute_labels=True)
brc.fit(dn)
c=brc.predict(dn)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-25-2cc03087defc> in <module>()
# ----> 1 from sklearn.cluster import Birch
#       2 n_samples=100
#       3 dn=np.transpose(np.reshape(menPixel[:,:,:,0:n_samples],(120*120*3,n_samples)))
#       4
#       5 brc = Birch(branching_factor=50, n_clusters=3, threshold=0.5,compute_labels=True)
#
# ImportError: cannot import name Birch

# %%
np.shape(dn)
# Out:
# (100, 43200)

# %%
C1=[]
C2=[]
C3=[]
# C4=[]
# C5=[]
for i in range(0,100):
    if c[i]==0:
        C1.append(np.reshape(dn[i,:],(120,120,3)))
    if c[i]==1:
        C2.append(np.reshape(dn[i,:],(120,120,3)))
    if c[i]==2:
        C3.append(np.reshape(dn[i,:],(120,120,3)))
#     if c[i]==3:
#         C2.append(np.reshape(dn[i,:],(120,120,3)))
#     if c[i]==4:
#         C3.append(np.reshape(dn[i,:],(120,120,3)))
subplot()        
multiple_image_show(C1)
multiple_image_show(C2)
multiple_image_show(C3)
# multiple_image_show(C4)
# multiple_image_show(C5)
# Out:
# Missing 4 Input Image/s
# Missing 2 Input Image/s
# Missing 1 Input Image/s

# %%
shape(C2)
# Out:
# (248, 120, 120, 3)

# %%
plt.hist(c)
# Out:
# (array([ 44.,   0.,   0.,   0.,   0.,  18.,   0.,   0.,   0.,  38.]),
#  array([ 0. ,  0.2,  0.4,  0.6,  0.8,  1. ,  1.2,  1.4,  1.6,  1.8,  2. ]),
#  <a list of 10 Patch objects>)

# %%
x=menPixel[:,:,:,0:2]
xx=np.reshape(x,[120,120,3,2],order=)
plt.imshow(xx[:,:,:,1])

# %%
import matplotlib.image as mpimg
import numpy as np
fig = plt.figure()

a=fig.add_subplot(5,5,1)

imgplot = plt.imshow(lum_img)
a=fig.add_subplot(1,2,2)
imgplot = plt.imshow(lum_img)

# %%
X[0][:]

# %%
from sklearn import cluster
from sklearn import metrics
from sklearn.metrics import pairwise_distances
from sklearn import preprocessing
from sklearn.cluster import DBSCAN

# %%
np.shape(menPixel)
# Out:
# (120, 120, 3, 9929)

# %%
dn=np.transpose(np.reshape(menPixel[:,:,:,0:100],(120*120*3,100)))

# %%
dn.shape
# Out:
# (100, 43200)

# %%
kmeans=cluster.KMeans(n_clusters=10,n_jobs=4)
kmeans.fit(dn)
# Out:
# KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=10, n_init=10,
#     n_jobs=4, precompute_distances=True, random_state=None, tol=0.0001,
#     verbose=0)

# %%
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

# %%
c=labels

# %%
np.sum(labels)
# Out:
# 429

# %%
for i in range(0,50):
    if (labels[i]==0):
        plt.imshow(menPixel[:,:,:,i])
        plt.show()

# %%
for i in range(0,50):
    if (labels[i]==1):
        plt.imshow(menPixel[:,:,:,i])
        plt.show()

# %%
plt.imshow(menPixel[:,:,:,1])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.imshow(menPixel[:,:,:,3])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ### EigenShoes

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA 
from sklearn import metrics

# %%
ds=np.transpose(np.reshape(menPixel[:,:,:,0:500],(120*120*3,500)))
np.shape(ds)
# Out:
# (500, 43200)

# %%
pca_Shoes=PCA(n_components=43200)
pca_Shoes.fit(ds)
# Out:
# PCA(copy=True, n_components=43200, whiten=False)

# %%
sho_components=pca_Shoes.components_

# %%
np.shape(sho_components)
# Out:
# (500, 43200)

# %%
print subjective_cols, '\n'
print '-------------------------------------\n'

for i, pc in enumerate(['PC1','PC2','PC3','PC4','PC5']):
    print pc, 'weighting vector:', subj_components[i]
    print '-------------------------------------\n'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-0486180e6ad7> in <module>()
# ----> 1 print subjective_cols, '\n'
#       2 print '-------------------------------------\n'
#       3
#       4 for i, pc in enumerate(['PC1','PC2','PC3','PC4','PC5']):
#       5     print pc, 'weighting vector:', subj_components[i]
#
# NameError: name 'subjective_cols' is not defined

# %%
Shoes_eigenvals = pca_Shoes.explained_variance_
explained_Variance = pca_Shoes.explained_variance_ratio_

print 'eigenvalues:', Shoes_eigenvals, '\n'
print 'explained variance:', explained_Variance

# %%
np.sum(explained_Variance)

# %%
ds_trans=pca_Shoes.transform(ds)

# %%
np.shape(ds_trans)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-d0f5746fc6ff> in <module>()
# ----> 1 np.shape(ds_trans)
#
# NameError: name 'ds_trans' is not defined
